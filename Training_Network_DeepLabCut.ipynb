# %% [markdown]
# **Script to run GPU for training network**

# %% [markdown]
# 1. Connect to T4 GPU runtime by clicking the three horizontal dots
# 2. Run first line of code that says "import"
# * If it give a numerical value, continue (e.g., 3.0.0)
# * If error, run !pip install deeplabcut and restart the session to reinstall DeepLabCut before the "import" line of code

# %%
import deeplabcut
print(deeplabcut.__version__)
# Out:
# 3.0.0

# %% [markdown]
# 3. After confirming that DeepLabCut is in this file, run the following:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 4. After mounted, you will need to check the name of your project to replace it in the command path. Then, run the code.

# %%
config_path = "/content/drive/MyDrive/Practice 2-Iara-2026-06-15/config.yaml"

deeplabcut.create_training_dataset(config_path)
deeplabcut.train_network(config_path)
# Out:
# Training with configuration:
# data:
#   bbox_margin: 20
#   colormode: RGB
#   inference:
#     normalize_images: True
#   train:
#     affine:
#       p: 0.5
#       rotation: 30
#       scaling: [0.5, 1.25]
#       translation: 0
#     crop_sampling:
#       width: 448
#       height: 448
#       max_shift: 0.1
#       method: hybrid
#     gaussian_noise: 12.75
#     motion_blur: True
#     normalize_images: True
# device: auto
# inference:
#   multithreading:
#     enabled: True
#     queue_length: 4
#     timeout: 30.0
#   compile:
#     enabled: False
#     backend: inductor
#   autocast:
#     enabled: False
# metadata:
#   project_path: /Users/iara/Desktop/Practice 2-Iara-2026-06-15
#   pose_config_path: /Users/iara/Desktop/Practice 2-Iara-2026-06-15/dlc-models-pytorch/iteration-0/Practice 2Jun15-trainset95shuffle1/train/pytorch_config.yaml
#   bodyparts: ['left_antena', 'right_antena', 'head', 'abdomen']
#   unique_bodyparts: []
#   individuals: ['animal']
# ...
